// %% [markdown]
// ## Question 4:
//
// declare a array of tuple like this
//
// val records = Array(
//   (1, "Alice", 85), (2, "Bob", 92), (3, "Charlie", 78), (4, "David", 66), (5, "Eve", 90),
//   (6, "Frank", 73), (7, "Grace", 88), (8, "Hannah", 91), (9, "Isaac", 84), (10, "Judy", 76),
//   (11, "Kevin", 82), (12, "Laura", 79), (13, "Mike", 95), (14, "Nina", 70), (15, "Oscar", 89),
//   (16, "Paul", 80), (17, "Quinn", 77), (18, "Rachel", 93), (19, "Sam", 85), (20, "Tina", 74),
//   (21, "Uma", 69), (22, "Victor", 96), (23, "Wendy", 87), (24, "Xander", 68), (25, "Yara", 94),
//   (26, "Zane", 81), (27, "Oliver", 78), (28, "Sophia", 85), (29, "Liam", 90), (30, "Mia", 83),
//   (31, "Noah", 88), (32, "Emma", 75), (33, "Ava", 92), (34, "William", 86), (35, "James", 91),
//   (36, "Lucas", 72), (37, "Amelia", 79), (38, "Ella", 89), (39, "Mason", 76), (40, "Logan", 95),
//   (41, "Ethan", 84), (42, "Charlotte", 82), (43, "Benjamin", 80), (44, "Alexander", 71),
//   (45, "Michael", 88), (46, "Isabella", 73), (47, "Daniel", 86), (48, "Elijah", 81),
//   (49, "Matthew", 79), (50, "Jackson", 92)
// )
//
// in the StudentOps function defined earlier
// add a function filterStudents(x:Student => Boolean): List[Student]
//
// and Array[Student] should be implicitly converted into List[Student]
//
// Eventhough we use record variable which is array type we must
// be able to call filterStudents
//
// Test the filterStudents functions with records variable

// %%
import scala.collection.mutable.ListBuffer
import scala.language.implicitConversions

case class Student(sno: Int, name: String, score: Int)

implicit class processStudentList(student: List[Student]) {
    def %>(cutoff: Int): List[Student] = {
        student.filter(_.score>cutoff)
    }

    def %<(cutoff: Int): List[Student] = {
        student.filter(_.score<cutoff)
    }
    def filterRecords(condition: Student => Boolean): List[Student] = {
        student.filter(condition)
}
}

implicit def convertTupleToStudent(student: (Int,String,Int)): Student = {
  Student(student._1, student._2, student._3)
}

// Using ListBuffer
/*implicit def convertArrayToList(studentArray: Array[Student]) : List[Student] = {
   var list: ListBuffer[Student] = new ListBuffer()
   for(index <- 0 to studentArray.length-1){
    val student: Student = studentArray(index)
    list += new Student(student.sno, student.name, student.score)
   }
   list.toList
}*/


// Using list with for
implicit def convertArrayToList(studentArray:Array[Student]): List[Student] = {
    var list: List[Student] = List()
    for(index <- 0 to studentArray.length-1){
        list = studentArray(index) :: list
    }
    list
}


def printList(students:List[Student]) = {
    students.foreach(student => {
    println(s"${student.name} has scored ${student.score}%.")
    })
}

val records = Array(
  (1, "Alice", 85), (2, "Bob", 92), (3, "Charlie", 78), (4, "David", 66), (5, "Eve", 90),
  (6, "Frank", 73), (7, "Grace", 88), (8, "Hannah", 91), (9, "Isaac", 84), (10, "Judy", 76),
  (11, "Kevin", 82), (12, "Laura", 79), (13, "Mike", 95), (14, "Nina", 70), (15, "Oscar", 89),
  (16, "Paul", 80), (17, "Quinn", 77), (18, "Rachel", 93), (19, "Sam", 85), (20, "Tina", 74),
  (21, "Uma", 69), (22, "Victor", 96), (23, "Wendy", 87), (24, "Xander", 68), (25, "Yara", 94),
  (26, "Zane", 81), (27, "Oliver", 78), (28, "Sophia", 85), (29, "Liam", 90), (30, "Mia", 83),
  (31, "Noah", 88), (32, "Emma", 75), (33, "Ava", 92), (34, "William", 86), (35, "James", 91),
  (36, "Lucas", 72), (37, "Amelia", 79), (38, "Ella", 89), (39, "Mason", 76), (40, "Logan", 95),
  (41, "Ethan", 84), (42, "Charlotte", 82), (43, "Benjamin", 80), (44, "Alexander", 71),
  (45, "Michael", 88), (46, "Isabella", 73), (47, "Daniel", 86), (48, "Elijah", 81),
  (49, "Matthew", 79), (50, "Jackson", 92)
)

val recordsArray = new Array[Student](records.length)
var index=0
records.foreach(record => {
    recordsArray(index) = record
    index+=1
})
val studentList: List[Student] = recordsArray  // Implicitly converted to List[Student]
printList(studentList.filterRecords(st => st.score > 90))
// Out:
// Jackson has scored 92%.
// Logan has scored 95%.
// James has scored 91%.
// Ava has scored 92%.
// Yara has scored 94%.
// Victor has scored 96%.
// Rachel has scored 93%.
// Mike has scored 95%.
// Hannah has scored 91%.
// Bob has scored 92%.
// import scala.collection.mutable.ListBuffer
// import scala.language.implicitConversions
// defined class Student
// defined class processStudentList
// defined function convertTupleToStudent
// defined function convertArrayToList
// defined function printList
// records: Array[(Int, String, Int)] = Array(
//   (1, "Alice", 85),
//   (2, "Bob", 92),
//   (3, "Charlie", 78),
//   (4, "David", 66),
//   (5, "Eve", 90),
//   (6, "Frank", 73),
//   (7, "Grace", 88),
//   (8, "Hannah", 91),
//   (9, "Isaac", 84),
//   (10, "Judy", 76),
//   (11, "Kevin", 82),
//   (12, "Laura", 79),
//   (13, "Mike", 95),
//   (14, "Nina", 70),
//   (15, "Oscar", 89),
//   (16, "Paul", 80),
//   (17, "Quinn", 77),
//   (18, "Rachel", 93),
//   (19, "Sam", 85),
//   (20, "Tina", 74),
//   (21, "Uma", 69),
//   (22, "Victor", 96),
//   (23, "Wendy", 87),
//   (24, "Xander", 68),
//   (25, "Yara", 94),
//   (26, "Zane", 81),
//   (27, "Oliver", 78),
//   (28, "Sophia", 85),
//   (29, "Liam", 90),
//   (30, "Mia", 83),
//   (31, "Noah", 88),
//   (32, "Emma", 75),
//   (33, "Ava", 92),
//   (34, "William", 86),
//   (35, "James", 91),
//   (36, "Lucas", 72),
//   (37, "Amelia", 79),
//   (38, "Ella", 89),
// ...
// recordsArray: Array[Student] = Array(
//   Student(sno = 1, name = "Alice", score = 85),
//   Student(sno = 2, name = "Bob", score = 92),
//   Student(sno = 3, name = "Charlie", score = 78),
//   Student(sno = 4, name = "David", score = 66),
//   Student(sno = 5, name = "Eve", score = 90),
//   Student(sno = 6, name = "Frank", score = 73),
//   Student(sno = 7, name = "Grace", score = 88),
//   Student(sno = 8, name = "Hannah", score = 91),
//   Student(sno = 9, name = "Isaac", score = 84),
//   Student(sno = 10, name = "Judy", score = 76),
//   Student(sno = 11, name = "Kevin", score = 82),
//   Student(sno = 12, name = "Laura", score = 79),
//   Student(sno = 13, name = "Mike", score = 95),
//   Student(sno = 14, name = "Nina", score = 70),
//   Student(sno = 15, name = "Oscar", score = 89),
//   Student(sno = 16, name = "Paul", score = 80),
//   Student(sno = 17, name = "Quinn", score = 77),
//   Student(sno = 18, name = "Rachel", score = 93),
//   Student(sno = 19, name = "Sam", score = 85),
//   Student(sno = 20, name = "Tina", score = 74),
//   Student(sno = 21, name = "Uma", score = 69),
//   Student(sno = 22, name = "Victor", score = 96),
//   Student(sno = 23, name = "Wendy", score = 87),
//   Student(sno = 24, name = "Xander", score = 68),
//   Student(sno = 25, name = "Yara", score = 94),
//   Student(sno = 26, name = "Zane", score = 81),
//   Student(sno = 27, name = "Oliver", score = 78),
//   Student(sno = 28, name = "Sophia", score = 85),
//   Student(sno = 29, name = "Liam", score = 90),
//   Student(sno = 30, name = "Mia", score = 83),
//   Student(sno = 31, name = "Noah", score = 88),
//   Student(sno = 32, name = "Emma", score = 75),
//   Student(sno = 33, name = "Ava", score = 92),
//   Student(sno = 34, name = "William", score = 86),
//   Student(sno = 35, name = "James", score = 91),
//   Student(sno = 36, name = "Lucas", score = 72),
//   Student(sno = 37, name = "Amelia", score = 79),
//   Student(sno = 38, name = "Ella", score = 89),
// ...
// index: Int = 50
// studentList: List[Student] = List(
//   Student(sno = 50, name = "Jackson", score = 92),
//   Student(sno = 49, name = "Matthew", score = 79),
//   Student(sno = 48, name = "Elijah", score = 81),
//   Student(sno = 47, name = "Daniel", score = 86),
//   Student(sno = 46, name = "Isabella", score = 73),
//   Student(sno = 45, name = "Michael", score = 88),
//   Student(sno = 44, name = "Alexander", score = 71),
//   Student(sno = 43, name = "Benjamin", score = 80),
//   Student(sno = 42, name = "Charlotte", score = 82),
//   Student(sno = 41, name = "Ethan", score = 84),
//   Student(sno = 40, name = "Logan", score = 95),
//   Student(sno = 39, name = "Mason", score = 76),
//   Student(sno = 38, name = "Ella", score = 89),
//   Student(sno = 37, name = "Amelia", score = 79),
//   Student(sno = 36, name = "Lucas", score = 72),
//   Student(sno = 35, name = "James", score = 91),
//   Student(sno = 34, name = "William", score = 86),
//   Student(sno = 33, name = "Ava", score = 92),
//   Student(sno = 32, name = "Emma", score = 75),
//   Student(sno = 31, name = "Noah", score = 88),
//   Student(sno = 30, name = "Mia", score = 83),
//   Student(sno = 29, name = "Liam", score = 90),
//   Student(sno = 28, name = "Sophia", score = 85),
//   Student(sno = 27, name = "Oliver", score = 78),
//   Student(sno = 26, name = "Zane", score = 81),
//   Student(sno = 25, name = "Yara", score = 94),
//   Student(sno = 24, name = "Xander", score = 68),
//   Student(sno = 23, name = "Wendy", score = 87),
//   Student(sno = 22, name = "Victor", score = 96),
//   Student(sno = 21, name = "Uma", score = 69),
//   Student(sno = 20, name = "Tina", score = 74),
//   Student(sno = 19, name = "Sam", score = 85),
//   Student(sno = 18, name = "Rachel", score = 93),
//   Student(sno = 17, name = "Quinn", score = 77),
//   Student(sno = 16, name = "Paul", score = 80),
//   Student(sno = 15, name = "Oscar", score = 89),
//   Student(sno = 14, name = "Nina", score = 70),
//   Student(sno = 13, name = "Mike", score = 95),
// ...

// %% [markdown]
// #### Note:
// For Implicit conversion from Array to List, we can use ListBuffer or we can use list but with list, new list is created every time hence it is not feasible for big data. As a practice, Implicit conversion from collection to collection should be avoided.
